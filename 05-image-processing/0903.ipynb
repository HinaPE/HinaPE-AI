# %%
import skimage as ski
from matplotlib import pyplot as plt
print(ski.__version__)
# Out:
# 0.24.0

# %%
camera = ski.data.camera()
camera.shape
# Out:
# (512, 512)

# %%
coins = ski.data.coins()
coins.shape
# Out:
# (303, 384)

# %%
cloud = ski.io.imread("clouds/clouds02.jpg")
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 711.5, 399.5, -0.5)
